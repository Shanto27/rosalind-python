# %%
from rosalind import translate_rna

# %%
rna_string = open('rosalind_prot.txt').readlines()[0]
# rna_string = 'AUGGCCAUGGCGCCCAGAACUGAGAUCAAUAGUACCCGUAUUAACGGGUGA'

# %%
print(''.join(translate_rna(rna_string)))
# Out:
# ...
