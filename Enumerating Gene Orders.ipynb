# %%
from rosalind import perm

# %%
f = open('rosalind_perm.txt').readline()
l = ''.join(str(n) for n in range(1,int(f)+1))
print(l)
# Out:
# 12345

# %%
l, p, s = perm(l)

# %%
print(l)
print(p)
print(s)
# Out:
# 120
# ...
